# %%
# Importando o 'pyplot' do 'matplotlib'
from matplotlib import pyplot as plt

# %%
nomes = ["Abraão", "Anthony", "Lucas", "Henry", "Amorim"]
idades = [22, 19, 19, 18, 19]
plt.bar(range(len(nomes)), idades) # o 'plt.bar' é utilizado para criar gráficos de barra
# isto é, gráficos de barras são utilizados para comparação 
plt.title("Nomes")
plt.ylabel("Idades")
plt.xticks(range(len(nomes)), nomes)
# Out:
# ([<matplotlib.axis.XTick at 0x20ea34ff390>,
#   <matplotlib.axis.XTick at 0x20ea34fea10>,
#   <matplotlib.axis.XTick at 0x20ea34fe290>,
#   <matplotlib.axis.XTick at 0x20ea35351d0>,
#   <matplotlib.axis.XTick at 0x20ea3537bd0>],
#  [Text(0, 0, 'Abraão'),
#   Text(1, 0, 'Anthony'),
#   Text(2, 0, 'Lucas'),
#   Text(3, 0, 'Henry'),
#   Text(4, 0, 'Amorim')])

# %%
from collections import Counter
import matplotlib.pyplot as plt

grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]
decile = lambda grade: grade // 10 * 10
histogram = Counter(decile(grade) for grade in grades)

plt.bar([x - 4 for x in histogram.keys()], histogram.values(), width=8)
plt.axis([-5, 105, 0, 5])
plt.xticks([10 * i for i in range(11)])
plt.xlabel("Decil")
plt.ylabel("# de Alunos")
plt.title("Distribuição das Notas do Teste 1")
plt.show()

# %%
lista_1 = ["A", "B", "C"]
lista_2 = [20, 30, 40]
# primeiro parâmetro: eixo x,
# segundo parâmetro: eixo y,
# terceiro parâmetro: largura das barras
plt.bar(lista_1, lista_2, 0.6) # x e y (x, y)
plt.xticks(lista_1)
# Out:
# ([<matplotlib.axis.XTick at 0x1bdc225eb50>,
#   <matplotlib.axis.XTick at 0x1bdc225f290>,
#   <matplotlib.axis.XTick at 0x1bdc245c7d0>],
#  [Text(0.0, 0, 'A'), Text(1.0, 0, 'B'), Text(2.0, 0, 'C')])

# %%
plt.barh(lista_1, lista_2, 0.6) # x e y (x, y)
# Out:
# <BarContainer object of 3 artists>
